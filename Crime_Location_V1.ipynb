# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
from ast import literal_eval
from mpl_toolkits.basemap import Basemap
from mapsplotlib import mapsplot as mplt
mplt.register_api_key('AIzaSyDewUCe0_xt4mBs6rbyxCupx1SS5UYwx_c')
import pandas as pd
import seaborn as sns

# %%
crime = pd.read_csv('Crime_Data_from_2010_to_Present.csv')
crime.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0    1208575    03/14/2013    03/11/2013           1800       12  77th Street
# 1  102005556    01/25/2010    01/22/2010           2300       20      Olympic
# 2        418    03/19/2013    03/18/2013           2030       18    Southeast
# 3  101822289    11/11/2010    11/10/2010           1800       18    Southeast
# 4   42104479    01/11/2014    01/04/2014           2300       21      Topanga
#
#    Reporting District  Crime Code                    Crime Code Description  \
# 0                1241         626         INTIMATE PARTNER - SIMPLE ASSAULT
# 1                2071         510                          VEHICLE - STOLEN
# 2                1823         510                          VEHICLE - STOLEN
# 3                1803         510                          VEHICLE - STOLEN
# 4                2133         745  VANDALISM - MISDEAMEANOR ($399 OR UNDER)
#
#               MO Codes          ...           \
# 0  0416 0446 1243 2000          ...
# 1                  NaN          ...
# 2                  NaN          ...
# 3                  NaN          ...
# 4                 0329          ...
#
#                                Weapon Description Status Code  \
# 0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)          AO
# 1                                             NaN          IC
# 2                                             NaN          IC
# 3                                             NaN          IC
# 4                                             NaN          IC
#
#   Status Description  Crime Code 1 Crime Code 2  Crime Code 3 Crime Code 4  \
# 0        Adult Other         626.0          NaN           NaN          NaN
# 1        Invest Cont         510.0          NaN           NaN          NaN
# 2        Invest Cont         510.0          NaN           NaN          NaN
# 3        Invest Cont         510.0          NaN           NaN          NaN
# 4        Invest Cont         745.0          NaN           NaN          NaN
#
#                                    Address Cross Street             Location
# 0  6300    BRYNHURST                    AV          NaN  (33.9829, -118.3338)
# 1                                 VAN NESS         15TH  (34.0454, -118.3157)
# 2   200 E  104TH                        ST          NaN   (33.942, -118.2717)
# 3                                     88TH         WALL  (33.9572, -118.2717)
# 4  7200    CIRRUS                       WY          NaN  (34.2009, -118.6369)
#
# [5 rows x 26 columns]

# %%
###Crime Type###

# %%
crime_type = crime['Crime Code Description'].value_counts()[:20]
crime_type.index.tolist()
# Out:
# ['BATTERY - SIMPLE ASSAULT',
#  'BURGLARY FROM VEHICLE',
#  'VEHICLE - STOLEN',
#  'BURGLARY',
#  'THEFT PLAIN - PETTY ($950 & UNDER)',
#  'THEFT OF IDENTITY',
#  'INTIMATE PARTNER - SIMPLE ASSAULT',
#  'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS) 0114',
#  'VANDALISM - MISDEAMEANOR ($399 OR UNDER)',
#  'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#  'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#  'ROBBERY',
#  'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD0036',
#  'CRIMINAL THREATS - NO WEAPON DISPLAYED',
#  'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#  'THEFT FROM MOTOR VEHICLE - GRAND ($400 AND OVER)',
#  'DOCUMENT FORGERY / STOLEN FELONY',
#  'OTHER MISCELLANEOUS CRIME',
#  'VIOLATION OF COURT ORDER',
#  'LETTERS, LEWD']

# %%
#plt.figure()
crime_type.plot(kind='barh')
plt.ylim(plt.ylim()[::-1])
plt.title('Number of Crimes by Crime Type')
plt.ylabel('Crime Type')
plt.xlabel('Number of crimes')
plt.show()

# %%
###Location Type###

# %%
crime_premise = crime['Premise Description'].value_counts()[:20]

# %%
#plt.figure()
crime_premise.plot(kind='barh')
plt.ylim(plt.ylim()[::-1])
plt.title('Number of Crimes by Location')
plt.ylabel('Crime Location')
plt.xlabel('Number of crimes')
plt.show()

# %%
###Crime Type and Location Type###

# %%
crime_20 = crime[crime['Crime Code Description'].isin(crime_type.index.tolist())]
crime_20 = crime_20[crime_20['Premise Description'].isin(crime_premise.index.tolist())]
crime_20.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0    1208575    03/14/2013    03/11/2013           1800       12  77th Street
# 1  102005556    01/25/2010    01/22/2010           2300       20      Olympic
# 2        418    03/19/2013    03/18/2013           2030       18    Southeast
# 3  101822289    11/11/2010    11/10/2010           1800       18    Southeast
# 4   42104479    01/11/2014    01/04/2014           2300       21      Topanga
#
#    Reporting District  Crime Code                    Crime Code Description  \
# 0                1241         626         INTIMATE PARTNER - SIMPLE ASSAULT
# 1                2071         510                          VEHICLE - STOLEN
# 2                1823         510                          VEHICLE - STOLEN
# 3                1803         510                          VEHICLE - STOLEN
# 4                2133         745  VANDALISM - MISDEAMEANOR ($399 OR UNDER)
#
#               MO Codes          ...           \
# 0  0416 0446 1243 2000          ...
# 1                  NaN          ...
# 2                  NaN          ...
# 3                  NaN          ...
# 4                 0329          ...
#
#                                Weapon Description Status Code  \
# 0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)          AO
# 1                                             NaN          IC
# 2                                             NaN          IC
# 3                                             NaN          IC
# 4                                             NaN          IC
#
#   Status Description  Crime Code 1 Crime Code 2  Crime Code 3 Crime Code 4  \
# 0        Adult Other         626.0          NaN           NaN          NaN
# 1        Invest Cont         510.0          NaN           NaN          NaN
# 2        Invest Cont         510.0          NaN           NaN          NaN
# 3        Invest Cont         510.0          NaN           NaN          NaN
# 4        Invest Cont         745.0          NaN           NaN          NaN
#
#                                    Address Cross Street             Location
# 0  6300    BRYNHURST                    AV          NaN  (33.9829, -118.3338)
# 1                                 VAN NESS         15TH  (34.0454, -118.3157)
# 2   200 E  104TH                        ST          NaN   (33.942, -118.2717)
# 3                                     88TH         WALL  (33.9572, -118.2717)
# 4  7200    CIRRUS                       WY          NaN  (34.2009, -118.6369)
#
# [5 rows x 26 columns]

# %%
location_by_type  = crime_20.pivot_table(values='DR Number', index='Premise Description', 
                                       columns='Crime Code Description', aggfunc=np.size).fillna(0)

# %%
location_by_type.head()
# Out:
# Crime Code Description  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  \
# Premise Description
# ALLEY                                                           1469.0
# DEPARTMENT STORE                                                  39.0
# DRIVEWAY                                                        1208.0
# DRUG STORE                                                        73.0
# GARAGE/CARPORT                                                   215.0
#
# Crime Code Description  BATTERY - SIMPLE ASSAULT  BURGLARY  \
# Premise Description
# ALLEY                                     1338.0      16.0
# DEPARTMENT STORE                           257.0     520.0
# DRIVEWAY                                  1780.0      57.0
# DRUG STORE                                 308.0     489.0
# GARAGE/CARPORT                             403.0    3937.0
#
# Crime Code Description  BURGLARY FROM VEHICLE  \
# Premise Description
# ALLEY                                   956.0
# DEPARTMENT STORE                         18.0
# DRIVEWAY                               7925.0
# DRUG STORE                                3.0
# GARAGE/CARPORT                         9432.0
#
# Crime Code Description  CRIMINAL THREATS - NO WEAPON DISPLAYED  \
# Premise Description
# ALLEY                                                    268.0
# DEPARTMENT STORE                                          68.0
# DRIVEWAY                                                 488.0
# DRUG STORE                                                90.0
# GARAGE/CARPORT                                            96.0
#
# Crime Code Description  DOCUMENT FORGERY / STOLEN FELONY  \
# Premise Description
# ALLEY                                                1.0
# DEPARTMENT STORE                                   207.0
# DRIVEWAY                                            11.0
# DRUG STORE                                         110.0
# GARAGE/CARPORT                                       7.0
#
# Crime Code Description  INTIMATE PARTNER - SIMPLE ASSAULT  LETTERS, LEWD  \
# Premise Description
# ALLEY                                               422.0            1.0
# DEPARTMENT STORE                                     13.0            9.0
# DRIVEWAY                                            564.0           10.0
# DRUG STORE                                           18.0            8.0
# GARAGE/CARPORT                                      196.0            4.0
#
# Crime Code Description  OTHER MISCELLANEOUS CRIME  ROBBERY  \
# Premise Description
# ALLEY                                       153.0   1267.0
# DEPARTMENT STORE                             38.0    709.0
# DRIVEWAY                                    320.0    491.0
# DRUG STORE                                   16.0   1110.0
# GARAGE/CARPORT                              138.0    148.0
#
# Crime Code Description  SHOPLIFTING - PETTY THEFT ($950 & UNDER)  \
# Premise Description
# ALLEY                                                        3.0
# DEPARTMENT STORE                                         13790.0
# DRIVEWAY                                                     5.0
# DRUG STORE                                                3006.0
# GARAGE/CARPORT                                               8.0
#
# Crime Code Description  THEFT FROM MOTOR VEHICLE - GRAND ($400 AND OVER)  \
# Premise Description
# ALLEY                                                              165.0
# DEPARTMENT STORE                                                     6.0
# DRIVEWAY                                                          2775.0
# DRUG STORE                                                           2.0
# GARAGE/CARPORT                                                    1382.0
#
# Crime Code Description  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  \
# Premise Description
# ALLEY                                                             515.0
# DEPARTMENT STORE                                                    7.0
# DRIVEWAY                                                         6982.0
# DRUG STORE                                                          2.0
# GARAGE/CARPORT                                                   3271.0
#
# Crime Code Description  THEFT OF IDENTITY  THEFT PLAIN - PETTY ($950 & UNDER)  \
# Premise Description
# ALLEY                                 7.0                               296.0
# DEPARTMENT STORE                    295.0                              4648.0
# DRIVEWAY                             14.0                               618.0
# DRUG STORE                           61.0                              2054.0
# GARAGE/CARPORT                       30.0                              1968.0
#
# Crime Code Description  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD0036  \
# Premise Description
# ALLEY                                                               150.0
# DEPARTMENT STORE                                                    750.0
# DRIVEWAY                                                            386.0
# DRUG STORE                                                          247.0
# GARAGE/CARPORT                                                     1414.0
#
# Crime Code Description  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS) 0114  \
# Premise Description
# ALLEY                                                               384.0
# DEPARTMENT STORE                                                     79.0
# DRIVEWAY                                                           1580.0
# DRUG STORE                                                          110.0
# GARAGE/CARPORT                                                     1129.0
#
# Crime Code Description  VANDALISM - MISDEAMEANOR ($399 OR UNDER)  \
# Premise Description
# ALLEY                                                      381.0
# DEPARTMENT STORE                                            62.0
# DRIVEWAY                                                  1164.0
# DRUG STORE                                                  85.0
# GARAGE/CARPORT                                             938.0
#
# Crime Code Description  VEHICLE - STOLEN  VIOLATION OF COURT ORDER
# Premise Description
# ALLEY                              756.0                      80.0
# DEPARTMENT STORE                     0.0                       8.0
# DRIVEWAY                          6176.0                     105.0
# DRUG STORE                           0.0                       5.0
# GARAGE/CARPORT                    3279.0                      29.0

# %%
from sklearn.cluster import AgglomerativeClustering as AC

# %%
df = location_by_type
df_norm = (df - df.mean()) / (df.max() - df.min()) + 0.25
ix = AC(3).fit(df_norm.T).labels_.argsort() # a trick to make better heatmaps
plt.figure(figsize=(17,13))
plt.imshow(df_norm.T.iloc[ix,:], cmap='Blues')
plt.colorbar(fraction=0.03)
plt.xticks(np.arange(df_norm.shape[0]), df_norm.index, rotation='vertical')
plt.yticks(np.arange(df_norm.shape[1]), df_norm.columns)
plt.title('Location Frequency for Each Crime')
plt.grid(False)
plt.show()

# %%
df = location_by_type
# 1: substract mean
df_norm=df.sub(df.mean(axis=1), axis=0)
# 2: divide by standard dev
df_norm=df_norm.div(df.std(axis=1), axis=0 )
ix = AC(3).fit(df_norm.T).labels_.argsort() # a trick to make better heatmaps
plt.figure(figsize=(17,13))
plt.imshow(df_norm.T.iloc[ix,:], cmap='Blues')
plt.colorbar(fraction=0.03)
plt.xticks(np.arange(df.shape[0]), df_norm.index, rotation='vertical')
plt.yticks(np.arange(df.shape[1]), df_norm.columns)
plt.title('Location Frequency for Each Crime')
plt.grid(False)
plt.show()

# %%
df = location_by_type
ix = AC(3).fit(df.T).labels_.argsort() # a trick to make better heatmaps
plt.figure(figsize=(17,13))
plt.imshow(df.T.iloc[ix,:], cmap='Blues')
plt.colorbar(fraction=0.03)
plt.xticks(np.arange(df.shape[0]), df.index, rotation='vertical')
plt.yticks(np.arange(df.shape[1]), df.columns)
plt.title('Location Frequency for Each Crime')
plt.grid(False)
plt.show()

# %%
# %matplotlib inline
sns.heatmap(df, annot=False)

# %%
sns.heatmap(df_norm)

# %%
# Normalize it by row:

# 1: substract mean
df_norm_row=df.sub(df.mean(axis=1), axis=0)
# 2: divide by standard dev
df_norm_row=df_norm_row.div(df.std(axis=1), axis=0 )

# Nomalized heatmap
sns.heatmap(df_norm_row) #cmap='viridis'#)

# %%
with open('Crime_Data_from_2010_to_Present.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    time = []
    date = []
    location = []
    location_2011 = []
    location_2012 = []
    location_2013 = []
    location_2014 = []
    location_2015 = []
    location_2016 = []
    location_2017 = []
    
    for row in reader:
        if row["Time Occurred"] != "":
            time.append(int(row["Time Occurred"]))
        if row["Date Occurred"] != "":
            date.append(row["Date Occurred"])
            m, d, y = row["Date Occurred"].split('/')

        if row["Location "] != "" and row["Location "] != "(0, 0)":
            location.append(literal_eval(row["Location "]))
            if y == "2011":
                location_2011.append(literal_eval(row["Location "]))
            elif y == "2012":
                location_2012.append(literal_eval(row["Location "]))
            elif y == "2013":
                location_2013.append(literal_eval(row["Location "]))
            elif y == "2014":
                location_2014.append(literal_eval(row["Location "]))
            elif y == "2015":
                location_2015.append(literal_eval(row["Location "]))
            elif y == "2016":
                location_2016.append(literal_eval(row["Location "]))
            elif y == "2017":
                location_2017.append(literal_eval(row["Location "]))

# %%
lons = []
lats = []
for pair in location:
    lons.append(pair[1])
    lats.append(pair[0])

# %%
#Using mapsplotlib#

# %%
df = pd.DataFrame.from_records(location)

# %%
mplt.density_plot(df[0], df[1])

# %%
#Using gmaps#

# %%
import gmaps
gmaps.configure(api_key="AIzaSyDewUCe0_xt4mBs6rbyxCupx1SS5UYwx_c") # Your Google API key

# load a Numpy array of (latitude, longitude) pairs
locations = np.asarray(location)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-21e581df62cb> in <module>()
#       3
#       4 # load a Numpy array of (latitude, longitude) pairs
# ----> 5 locations = np.asarray(location)
#
# NameError: name 'location' is not defined

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations))
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-5aa088c03196> in <module>()
#       1 fig = gmaps.figure()
# ----> 2 fig.add_layer(gmaps.heatmap_layer(locations))
#       3 fig
#
# NameError: name 'locations' is not defined

# %%
#Using Basemap#

# %%
map = Basemap(projection='merc', lat_0=34.05223, lon_0=-118.24368,
              resolution='f', area_thresh=0.01, 
              llcrnrlon=-118.7, llcrnrlat=33.8,
              urcrnrlon=-118.108, urcrnrlat=34.38)
 
map.drawcoastlines()
map.drawcounties()
map.fillcontinents(color='coral')
map.drawmapboundary()

# %%
x,y = map(lons, lats)
map.plot(x, y, 'bo', markersize=0.005)
plt.show()
