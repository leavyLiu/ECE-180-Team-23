# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./Crime_Data_from_2010_to_Present.csv")

# %%
data.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0    1208575    03/14/2013    03/11/2013           1800       12  77th Street
# 1  102005556    01/25/2010    01/22/2010           2300       20      Olympic
# 2        418    03/19/2013    03/18/2013           2030       18    Southeast
# 3  101822289    11/11/2010    11/10/2010           1800       18    Southeast
# 4   42104479    01/11/2014    01/04/2014           2300       21      Topanga
#
#    Reporting District  Crime Code                    Crime Code Description  \
# 0                1241         626         INTIMATE PARTNER - SIMPLE ASSAULT
# 1                2071         510                          VEHICLE - STOLEN
# 2                1823         510                          VEHICLE - STOLEN
# 3                1803         510                          VEHICLE - STOLEN
# 4                2133         745  VANDALISM - MISDEAMEANOR ($399 OR UNDER)
#
# ...

# %%
data.columns
# Out:
# Index(['DR Number', 'Date Reported', 'Date Occurred', 'Time Occurred',
#        'Area ID', 'Area Name', 'Reporting District', 'Crime Code',
#        'Crime Code Description', 'MO Codes', 'Victim Age', 'Victim Sex',
#        'Victim Descent', 'Premise Code', 'Premise Description',
#        'Weapon Used Code', 'Weapon Description', 'Status Code',
#        'Status Description', 'Crime Code 1', 'Crime Code 2', 'Crime Code 3',
#        'Crime Code 4', 'Address', 'Cross Street', 'Location '],
#       dtype='object')

# %%
crime_code_discription_dict = dict(zip(data["Crime Code"].value_counts()[0:10].index, data["Crime Code Description"].value_counts()[0:10].index))
crime_code_discription_dict
# np.array(data_code_hist.index)
# explode = [0.1]*10
# plt.pie(np.array(data_code_hist.values))
# plt.bar(data_code_hist.index,np.array(data_code_hist.values))
# a = plt.pie(np.array(data_code_hist.values),labels= np.array(data_code_hist.index),autopct='%1.1f%%',explode=explode,shadow=True)
# Out:
# {230: 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#  310: 'BURGLARY',
#  330: 'BURGLARY FROM VEHICLE',
#  354: 'THEFT OF IDENTITY',
#  440: 'THEFT PLAIN - PETTY ($950 & UNDER)',
#  510: 'VEHICLE - STOLEN',
#  624: 'BATTERY - SIMPLE ASSAULT',
#  626: 'INTIMATE PARTNER - SIMPLE ASSAULT',
#  740: 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS) 0114',
#  745: 'VANDALISM - MISDEAMEANOR ($399 OR UNDER)'}

# %%
sns.barplot(data["Crime Code"].value_counts().index[0:30], data["Crime Code"].value_counts().values[0:30],)
# sns.despine(left=True, bottom=True)

# ax = sns.barplot(x='totalCount', y='Code', data=data["Crime Code"].value_counts())
# ax.set_xlabel('totalCount')

# %%
data["Crime Code"].value_counts().values[0:30]
# Out:
# array([154454, 129646, 129622, 121712, 120375, 106072,  91320,  85169,
#         75400,  72268,  68779,  67652,  59611,  46908,  37588,  24263,
#         19738,  17263,  17224,  16855,  15603,  14547,  11250,  10467,
#          9978,   9886,   9663,   9602,   8689,   7910])

# %%
data["Crime Code"].value_counts().index[0:30]
# Out:
# Int64Index([624, 330, 510, 310, 440, 354, 626, 740, 745, 230, 420, 210, 341,
#             930, 442, 331, 649, 956, 946, 900, 888, 901, 350, 320, 761, 236,
#             480, 220, 860, 121],
#            dtype='int64')

# %% [markdown]
# # victim age visualization

# %%
data['Victim Age'].hist(bins = 40)

# %%
data['Victim Age'].value_counts() # it shows that victim age has a peak during 15 and 16, interesting
# Out:
# 16.0    42535
# 25.0    39227
# 15.0    38776
# 24.0    38238
# 26.0    37981
# 27.0    37492
# 23.0    37061
# 28.0    36749
# 29.0    36543
# 30.0    35915
# 22.0    34382
# 31.0    33837
# 14.0    33263
# 32.0    33261
# 35.0    32462
# 33.0    32292
# 34.0    31950
# 21.0    31697
# 36.0    29880
# 40.0    28518
# 37.0    28467
# 20.0    28282
# 13.0    28202
# 38.0    27767
# 39.0    27605
# 42.0    26328
# 41.0    26318
# 43.0    26146
# 12.0    26015
# 11.0    26004
#         ...
# 70.0     5535
# 71.0     4749
# 72.0     4466
# 73.0     3870
# 74.0     3519
# 75.0     3476
# 76.0     2951
# 77.0     2766
# 78.0     2529
# 79.0     2319
# 80.0     2225
# 81.0     1865
# 82.0     1740
# 83.0     1594
# 84.0     1471
# 85.0     1275
# 86.0     1135
# 87.0      978
# 88.0      912
# 89.0      730
# 90.0      666
# 91.0      507
# 92.0      402
# 99.0      377
# 93.0      356
# 94.0      287
# 95.0      196
# 96.0      143
# 97.0      107
# 98.0       75
# ...

# %% [markdown]
# # relationship between age and crime code

# %%
Victim_age_crime_sex = data[['Victim Age','Crime Code','Victim Sex']].dropna()
top10_crime = data["Crime Code"].value_counts()[:10].index
counter = 1
for crime_code in top10_crime:
    plt.figure()
    data_wrt_crime = Victim_age_crime_sex[Victim_age_crime_sex['Crime Code'] == crime_code]
    data_wrt_crime['Victim Age'].hist(bins = 45)
    data_wrt_crime[data_wrt_crime['Victim Sex'] == 'F']['Victim Age'].hist(bins = 45)
    data_wrt_crime[data_wrt_crime['Victim Sex'] == 'M']['Victim Age'].hist(bins = 45)
    
   
    mean_ = Victim_age_crime_sex[Victim_age_crime_sex['Crime Code'] == crime_code]['Victim Age'].mean() 
    median_ = Victim_age_code[Victim_age_code['Crime Code'] == crime_code]['Victim Age'].median() 
    plt.axvline(x = mean_,color = 'r')
    plt.axvline(x = median_,color ='y')
    counter += 1
    plt.title(crime_code_discription_dict[crime_code])
# Victim_age_code['Crime Code']

# %% [markdown]
# # relationship between crime and sex

# %%
# data of age and sex
Victim_age_sex = data[['Victim Age','Victim Sex']].dropna() 
# Victim_age_sex[Victim_age_sex["Victim Sex"] == 'M']['Victim Sex'] = 1
# Victim_age_sex[Victim_age_sex["Victim Sex"] == 'F']['Victim Sex'] = -1

# %% [markdown]
# # relationship between area and crime

# %%
area_crime_code = data[['Area ID','Crime Code']].dropna()
for crime_code in top10_crime:
    plt.figure()
    area_crime_code[area_crime_code['Crime Code'] == crime_code]['Area ID'].hist()
    plt.title(crime_code_discription_dict[crime_code])
    plt.xlabel('Area Code')
# area_crime

# %% [markdown]
# # most security area

# %%
area_id = data['Area ID']
area_id.value_counts()
# Out:
# 12    117451
# 3     108861
# 15     91793
# 14     89162
# 18     88857
# 19     85005
# 11     81165
# 9      80450
# 13     79387
# 17     78611
# 21     78267
# 6      77497
# 20     75158
# 5      75040
# 1      72582
# 10     72096
# 2      71303
# 8      70543
# 7      68209
# 16     64659
# 4      61583
# Name: Area ID, dtype: int64
